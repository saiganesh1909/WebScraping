# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
url = 'https://www.brainyquote.com/topics/motivational-quotes'

# %%
r= requests.get(url)

# %%
print(r.content)
# Out:
# b'\n<!DOCTYPE html>\n<html lang="en">\n<head>\n<title>Motivational Quotes - BrainyQuote</title>\n<meta name="robots" content="all">\n<meta charset="utf-8" />\n<meta name="viewport" content="width=device-width, initial-scale=1.0, viewport-fit=cover"><meta name="description" content="Explore 285 Motivational Quotes by authors including Winston Churchill, Confucius, and Elon Musk at BrainyQuote.">\n<meta name="googlebot" content="NOODP">\n<meta property="ver" content="13.3.8:5165065">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="msapplication-config" content="none">\n<meta name="apple-mobile-web-app-capable" content="yes">\n<meta property="ts" content="1671827450">\n<meta property="og:site_name" content="BrainyQuote">\n<meta property="og:title" content="Motivational Quotes - BrainyQuote">\n<meta property="og:type" content="article">\n<meta property="og:description" content="Explore 285 Motivational Quotes by authors including Winston Churchill, Confucius, and Elon
# ...

# %% [markdown]
# - Now that we have the HTML content, we need to parse the data. For that, we will be using beautiful soup with a parser html5lib.

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(r.content,'html5lib')
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 soup = BeautifulSoup(r.content,'html5lib')
#
# File ~\anaconda3\lib\site-packages\bs4\__init__.py:248, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     246     builder_class = builder_registry.lookup(*features)
#     247     if builder_class is None:
# --> 248         raise FeatureNotFound(
#     249             "Couldn't find a tree builder with the features you "
#     250             "requested: %s. Do you need to install a parser library?"
#     251             % ",".join(features))
#     253 # At this point either we have a TreeBuilder instance in
#     254 # builder, or we have a builder_class that we can instantiate
#     255 # with the remaining **kwargs.
#     256 if builder is None:
#
# ...

# %%
pip install html5lib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
soup = BeautifulSoup(r.content,'html5lib')
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 soup = BeautifulSoup(r.content,'html5lib')
#
# File ~\anaconda3\lib\site-packages\bs4\__init__.py:248, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     246     builder_class = builder_registry.lookup(*features)
#     247     if builder_class is None:
# --> 248         raise FeatureNotFound(
#     249             "Couldn't find a tree builder with the features you "
#     250             "requested: %s. Do you need to install a parser library?"
#     251             % ",".join(features))
#     253 # At this point either we have a TreeBuilder instance in
#     254 # builder, or we have a builder_class that we can instantiate
#     255 # with the remaining **kwargs.
#     256 if builder is None:
#
# ...

# %%
pip install html5lib

# %%
soup = BeautifulSoup(r.content,'html5lib')

# %%
table = soup.find('div',attrs={'id':'quotesList'})

# %%
print(table.prettify())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 print(table.prettify())
#
# NameError: name 'table' is not defined

# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
table = BeautifulSoup(r.content,'lxml')

# %%
print(r)
# Out:
# <Response [200]>

# %%
print(table.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    Motivational Quotes - BrainyQuote
#   </title>
#   <meta content="all" name="robots"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0, viewport-fit=cover" name="viewport"/>
#   <meta content="Explore 285 Motivational Quotes by authors including Winston Churchill, Confucius, and Elon Musk at BrainyQuote." name="description"/>
#   <meta content="NOODP" name="googlebot"/>
#   <meta content="13.3.8:5165065" property="ver"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="none" name="msapplication-config"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="1671827450" property="ts"/>
#   <meta content="BrainyQuote" property="og:site_name"/>
#   <meta content="Motivational Quotes - BrainyQuote" property="og:title"/>
#   <meta content="article" property="og:type"/>
# ...

# %%
for row in table.findAll('div',attrs={'class':'qti-listm'}):
    quote={}
    quotes=[]
    try:
        quote['author'] = row.img['alt'].split('-')[1]
        quote['text'] = row.img['alt'].split('-')[0]
        quotes.append(quote)
    except TypeError:
        continue
# Out:
#   Input In [59]
#     print(quote['author'] = row.img['alt'].split('-')[1])
#           ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?
